# %% [markdown]
# # Chap no 7

# %%
stuff = "Hello\nWorld!" #this \n will consider one elemnet and it breaks the line
print(stuff)
# Out:
# Hello
# World!

# %%
len(stuff) #give 12 cuz hello world is 11 and one is \n
# Out:
# 12

# %%
xfile = open('mbox (2).txt')
for chees in xfile:
 print(chees)
# Out:
# {
#
#  "cells": [
#
#   {
#
#    "cell_type": "markdown",
#
#    "id": "2616156c",
#
#    "metadata": {},
#
#    "source": [
#
#     "# Chapter # 5"
#
#    ]
#
#   },
#
#   {
#
#    "cell_type": "markdown",
#
#    "id": "b530a03a",
#
#    "metadata": {},
#
#    "source": [
#
#     "**LOOPS**"
#
#    ]
#
#   },
#
#   {
#
#    "cell_type": "code",
#
#    "execution_count": 2,
#
#    "id": "8afe437f",
#
#    "metadata": {},
#
#    "outputs": [
#
#     {
#
#      "name": "stdout",
#
#      "output_type": "stream",
#
#      "text": [
#
#       "5\n",
#
#       "4\n",
#
#       "3\n",
#
#       "2\n",
#
#       "1\n",
#
#       "Blastoff!\n",
#
#       "0\n"
#
#      ]
#
#     }
#
#    ],
#
#    "source": [
#
#     "n = 5\n",
#
#     "while n > 0 :\n",
#
#     " print(n)\n",
#
#     " n = n - 1\n",
#
#     "print('Blastoff!')\n",
#
#     "print(n)"
#
#    ]
#
#   },
#
#   {
#
#    "cell_type": "markdown",
#
#    "id": "c80a027e",
#
#    "metadata": {},
#
#    "source": [
#
# ...

# %%
fhand = open('mbox (2).txt')
count = 0
for line in fhand:
 count = count + 1
print('Line Count:', count)
# Out:
# Line Count: 422

# %%
fhand = open('mbox (2).txt')
inp = fhand.read()
print(len(inp))
# Out:
# 7603

# %%
print(inp[:20])
# Out:
# {
#  "cells": [
#   {

# %%
phand = open('mbox (2).txt')
for line in phand:
  if line.startswith('From:') :
    print(line)

# %%
fhand = open('mbox (2).txt')
for line in fhand:
  line = line.rstrip()
  if line.startswith('From:') :
   print(line)

# %%
fhand = open('mbox (2).txt')
for line in fhand:
 line = line.rstrip()
 if not line.startswith('From:') :
  continue
print(line)
# Out:
# }

# %%
fname = input('Enter the file name: ')
fhand = open(fname)
count = 0
for line in fhand:
 if line.startswith('Subject:') :
  count = count + 1
print('There were', count, 'subject lines in', fname)

# %%
fname = input('Enter the file name: ')
try:
  fhand = open(fname)
except:
  print('File cannot be opened:', fname)
  quit()
count = 0
for line in fhand:
  if line.startswith('Subject:') :
   count = count + 1
 print('There were', count, 'subject lines in', fname)
